-- %%
%sql
-- Cell 1: Keywords inside string literals, comments, and identifiers
-- select * from ignored_comment_table
SELECT col_select AS `from`,
       'select * from literal_table' AS query_text
FROM test_catalog.test_schema.test_table_where
WHERE status = 'inactive' AND col_select IS NOT NULL;

-- %%
%sql
Use catalog test_catalog;
use schema test_schema;

-- %%
%sql
-- Cell 2: Mixed-case and lowercase keywords
select id, name
fRoM registered_users
wHeRe status = 'active' and points >= 20;

-- %%
%sql
-- Cell 3: SQL Syntax error (parsing failure)
SELECT FROM where OR;;

-- %%
%python
# PySpark code in edge case notebook
my_table = "usr_adts"
spark.sql(f"selec id, event_type fRoM {my_table} wHeRe event_type = 'SIGNUP'")
